# %% [markdown]
# # Database visualization
#
# ## Load database

# %%
# importing pandas
import pandas as pd
 
# reading pickle
df = pd.read_pickle('simulations_df.pkl')
 
# set the max columns to none
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)


print(df.shape)
display(df)
# Out:
# (152, 16)
#      protein small_molec  conc  lambd  sigma   temp  \
# 0    Q5-8_20         GLY  20.0  0.000  2.099  290.0
# 1    Q5-8_20         GLY  20.0  0.000  2.099  300.0
# 2    Q5-8_20         GLY  20.0  0.000  2.099  340.0
# 3    Q5-8_20         GLY  20.0  0.000  2.099  323.0
# 4    Q5-8_20         GLY  20.0  0.350  2.099  323.0
# 5    Q5-8_20         GLY  20.0  0.525  2.099  323.0
# 6    Q5-8_20         GLY  20.0  0.700  2.099  290.0
# 7    Q5-8_20         GLY  20.0  0.700  2.099  300.0
# 8    Q5-8_20         GLY  20.0  0.700  2.099  323.0
# 9    Q5-8_20         GLY  20.0  0.525  0.970  323.0
# 10   Q5-8_20         GLY  20.0  0.000  0.970  323.0
# 11   Q5-8_20         GLY  20.0  0.700  0.970  290.0
# 12   Q5-8_20         GLY  20.0  0.700  0.970  300.0
# 13   Q5-8_20         GLY  20.0  0.700  0.970  323.0
# 14   Q5-8_20         GLY  20.0  0.350  0.970  323.0
# 15   Q5-8_20         GLY  10.0  0.700  0.450  310.0
# 16   Q5-8_20         GLY  10.0  0.700  0.450  320.0
# ...

# %%
def choose_cmap_color(value, prop, PROTEINS, DRUGS, CONC, TEMPS, LAMBDAS):

    # TEMPS = [290, 300, 310, 315, 320, 323, 325, 330]
    # LAMBDAS = ["None", 0.0, 0.175, 0.35, 0.525, 0.7]
    # CONC = [0.2, 2.0, 10, 20.0]
    print("conc:", CONC)

    if prop in ["temperature", "T", "temp", "t"]:
        col_arr = plt.cycler("color", plt.cm.viridis(np.linspace(0, 1, len(TEMPS))))
        col_val = np.array(col_arr)[TEMPS.index(value)]
        print("value: ", value)

    elif prop in ["lambda", "l", "lam", "lamb"]:
        # default plasma
        # cool in the YRD presentation
        col_arr = plt.cycler("color", plt.cm.plasma(np.linspace(0, 1, len(LAMBDAS))))
        col_val = np.array(col_arr)[LAMBDAS.index(value)]

    elif prop in ["conc", "c", "conc"]:
        col_arr = plt.cycler("color", plt.cm.winter(np.linspace(0, 1, len(CONC))))
        col_val = np.array(col_arr)[CONC.index(value)]

    elif prop in ["both"]:
        combin = list(itertools.product(TEMPS, LAMBDAS))
        # print("combin: ", combin)
        col_arr = plt.cycler("color", plt.cm.magma(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    elif prop in ["conc_temp"]:
        combin = list(itertools.product(TEMPS, CONC))
        col_arr = plt.cycler("color", plt.cm.cool(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    elif prop in ["conc_lambda", "lambda_conc"]:
        combin = list(itertools.product(LAMBDAS, CONC))
        print("combin: ", combin)
        print(value)
        col_arr = plt.cycler("color", plt.cm.viridis(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    elif prop in ["all", "conc_lambda_temp"]:
        combin = list(itertools.product(TEMPS, LAMBDAS, CONC))
        col_arr = plt.cycler("color", plt.cm.prism(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    return col_val["color"]

# %% [markdown]
# ## Testing queries

# %%
# display(df[df.temp == 350])
#df[df.small_molec == 'None'][df.small_molec == None]
# q = df.loc[(df.small_molec != 'GLY') ]
# display(q)

#df[df.lambd == 0][df.temp == 323][df.conc == 2]

#df[df.sim_time == '300000000'][df.conc == 20.0]

#q2 = df[df.temp == 310][df.conc == 20.0][df.sigma == 0.45][df.lambd == 0.175][df.sim_time == 43200].reset_index(drop=True)
query = df[df.temp == 323][df.conc == 20.0][df.sigma == 4.5]
display(query)
# Out:
# /tmp/ipykernel_35626/3868510250.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   query = df[df.temp == 323][df.conc == 20.0][df.sigma == 4.5]
#     protein small_molec  conc  lambd  sigma   temp  \
# 50  Q5-8_20         GLY  20.0    0.0    4.5  323.0
#
#                                           idp_average  \
# 50  [[0.0, 0.0], [1.0, 0.0], [2.0, 0.0], [3.0, 0.0...
#
#                                           drg_average                  hash  \
# 50  [[0.0, 3.262], [1.0, 3.238], [2.0, 3.237333333...  -2941473276514899454
#
#    extension   sim_time   time_unit  idp_plat_avg  drg_plat_avg  idp_dilu_avg  \
# 50      None  145000000  iterations    705.627684      0.000035     25.331338
#
#     drg_dilu_avg
# 50      3.098005

# %%
res = df[df.lambd == 0.350][df.conc == 20.0][df.sigma == 0.450].sort_values('temp', axis=0)
# Out:
# /tmp/ipykernel_35626/3504398067.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   res = df[df.lambd == 0.350][df.conc == 20.0][df.sigma == 0.450].sort_values('temp', axis=0)

# %% [markdown]
# ## Plot Linear Graphs from DB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
import itertools


# importing pandas
import pandas as pd
 
# reading pickle
df = pd.read_pickle('simulations_df.pkl')
 
# set the max columns to none
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

#print(df.shape)
#display(df)

def choose_cmap_color(value, prop, PROTEINS, DRUGS, CONC, TEMPS, LAMBDAS):

    # TEMPS = [290, 300, 310, 315, 320, 323, 325, 330]
    # LAMBDAS = ["None", 0.0, 0.175, 0.35, 0.525, 0.7]
    # CONC = [0.2, 2.0, 10, 20.0]
    print("conc:", CONC)

    if prop in ["temperature", "T", "temp", "t"]:
        col_arr = plt.cycler("color", plt.cm.viridis(np.linspace(0, 1, len(TEMPS))))
        col_val = np.array(col_arr)[TEMPS.index(value)]
        print("value: ", value)

    elif prop in ["lambda", "l", "lam", "lamb"]:
        # default plasma
        # cool in the YRD presentation
        col_arr = plt.cycler("color", plt.cm.plasma(np.linspace(0, 1, len(LAMBDAS))))
        col_val = np.array(col_arr)[LAMBDAS.index(value)]

    elif prop in ["conc", "c", "conc"]:
        col_arr = plt.cycler("color", plt.cm.winter(np.linspace(0, 1, len(CONC))))
        col_val = np.array(col_arr)[CONC.index(value)]

    elif prop in ["both"]:
        combin = list(itertools.product(TEMPS, LAMBDAS))
        # print("combin: ", combin)
        col_arr = plt.cycler("color", plt.cm.magma(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    elif prop in ["conc_temp"]:
        combin = list(itertools.product(TEMPS, CONC))
        col_arr = plt.cycler("color", plt.cm.cool(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    elif prop in ["conc_lambda", "lambda_conc"]:
        combin = list(itertools.product(LAMBDAS, CONC))
        print("combin: ", combin)
        print(value)
        col_arr = plt.cycler("color", plt.cm.viridis(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    elif prop in ["all", "conc_lambda_temp"]:
        combin = list(itertools.product(TEMPS, LAMBDAS, CONC))
        col_arr = plt.cycler("color", plt.cm.prism(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    return col_val["color"]


def plot_averages(type):

    # combin_all = itertools.product(CONC, TEMPS, LAMBDAS)
    # for comb in combin_all:
    #     prop_dict_T[comb[0]][comb[1]][comb[2]]
    #     print('prop_dict_T[comb[0]][comb[1]][comb[2]]: ', prop_dict_T[comb[0]][comb[1]][comb[2]])
    #     # prop_avg.append(prop_dict_T[20][T][lamb])
    # print('combin: ', list(combin))
    # quit()

    # combin = list(itertools.product(LAMBDAS, CONC))

    for cc in CONC:
        #print("\ncc: ", cc)
        for lamb in LAMBDAS:
            prop_avg = []
            #print("lamb: ", lamb)
            for T in TEMPS:
                entry = df.loc[(df.conc == cc) & (df.lambd == lamb) & (df.temp == T) & (df.sigma == 0.450)]
                if type == "idp":
                    try:
                        # print("entry.idp_average: ", entry.idp_plat_avg.values[0])
                        prop_avg.append(entry.idp_plat_avg.values[0])
                        #print("T: ", T, "avg", entry.idp_plat_avg.values[0])
                    except IndexError:
                        prop_avg.append(None)
                elif type == "drg":
                    try:
                        # print("entry.idp_average: ", entry.idp_plat_avg.values[0])
                        prop_avg.append(entry.drg_plat_avg.values[0])
                    except IndexError:
                        prop_avg.append(None)

            # prop_avg = []

            #print("T: ", T, "avg", entry.idp_plat_avg.values[0])
            col = choose_cmap_color(
                lamb, "lambda", ["Q5"], ["GLY"], CONC, TEMPS, LAMBDAS
            )

            if cc == 10.0:
                mark = "^"
            elif cc == 15.0:
                mark = "P"
            elif cc == 20.0:
                mark = "o"
            else:
                mark = "o"

            if type == "idp":
                label_text = f"$\\lambda$ = {lamb}\n{cc}mM"
            elif type == "drg":
                label_text = f"$\\lambda$ = {lamb}\n{cc}mM"

            # Checking if there is any "None" value in the average list (if the
            # simulation has not been performed)
            prop_avg = np.array(prop_avg)
            mask = pd.isnull(prop_avg)
            prop_avg = (prop_avg[~mask])
            T_masked = (np.array(TEMPS)[~mask])
            
            # Converting the particle count to concentration
            # total cell volume in L: 3.375e-20
            # volume of the condensed phase: 4.275e-21
            # bin volume: 1e3*15e-9*15e-9*1e-9
            
            bin_vol = 1e3*15e-9*15e-9*1e-9
            x_conc = prop_avg * (1/6.02e23) * (1/bin_vol) * 1000 * (1/167)         
            
            #print("temp",T,"prop_avg: ", prop_avg)
            plt.plot(
                #prop_avg,
                x_conc,
                T_masked,
                markersize=20,
                marker=mark,
                linestyle=":",
                lw=5,
                color=col,
                label=label_text,
            )

  
    nodrg_entries = df[df.small_molec != 'GLY'][df.temp < 370]
    x_conc_idp = nodrg_entries.idp_plat_avg * (1/6.02e23) * (1/bin_vol) * 1000 * (1/167)
    
    plt.plot(
        #nodrg_entries.idp_plat_avg,
        x_conc_idp,
        nodrg_entries.temp,
        markersize=14,
        marker='o',
        linestyle="None",
        lw=5,
        color='cyan',
        label='NODRG',
        alpha=0.7,
        markeredgewidth=1.5,
        mec='black',
        #path_effects=[pe.Stroke(linewidth=1, foreground='black')],
    )

    plt.xlabel("Average concentration (mM)", fontsize=25)
    plt.legend(
        framealpha=0,
        fontsize=13,
        bbox_to_anchor=(0, 1, 1, 0),
        ncol=3,
        mode="expand",
        markerscale=0.8,
    )
    plt.ylabel("Temperature (K)", fontsize=25)
    # plt.yticks(
    #     [270, 280, 290, 300, 310, 320, 330, 340, 350],
    #     [270, 280, 290, 300, 310, 320, 330, 340, 350],
    # )
    #plt.grid()
    plt.tight_layout()
    # plt.subplots_adjust(top=.95)
    # plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=5, hspace=5)
 
    plt.savefig("all_lambdas_concentration.svg",dpi=500)
    plt.show()


TEMPS = [
    270,
    290,
    300,
    310,
    315,
    320,
    323,
    330,
    340,
    350,
    #370
]
LAMBDAS = [
    -0.7,
    #-0.1,
    0,
    0.175,
    0.350,
    0.525,
    0.7,
    0.9,
    # "None",
    # None,
]
CONC = [
    # 0.0,
    # None,
    # 0.2,
    # 2.0,
    # 10.0,
    # 15.0,
    20.0,
]


plt.rc("font", family="serif")
plt.rcParams.update({"font.size": 25})
plt.tick_params(labelsize=25)
plt.rcParams["axes.linewidth"] = 0.5
plt.style.use("seaborn-poster")

plot_averages(type="idp")
# Out:
# conc: [20.0]
# conc: [20.0]
# conc: [20.0]
# conc: [20.0]
# conc: [20.0]
# conc: [20.0]
# conc: [20.0]
# /tmp/ipykernel_42527/1469078911.py:152: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   nodrg_entries = df[df.small_molec != 'GLY'][df.temp < 370]

# %%
display(df[df.temp == 323][df.conc == 20.][df.lambd == 0.35][df.sigma == 0.45].sort_values('temp', axis=0))
# Out:
# /tmp/ipykernel_25477/1084045287.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   display(df[df.temp == 323][df.conc == 20.][df.lambd == 0.35][df.sigma == 0.45].sort_values('temp', axis=0))
#      protein small_molec  conc  lambd  sigma   temp  \
# 101  Q5-8_20         GLY  20.0   0.35   0.45  323.0
#
#                                            idp_average  \
# 101  [[0.0, 1.042], [1.0, 0.8253333333333334], [2.0...
#
#                                            drg_average                 hash  \
# 101  [[0.0, 2.942], [1.0, 3.03], [2.0, 2.934], [3.0...  1725672776475068535
#
#     extension   sim_time   time_unit  idp_plat_avg  drg_plat_avg  \
# 101      None  300000000  iterations    537.140351      1.820947
#
#      idp_dilu_avg  drg_dilu_avg
# 101     49.945738      2.834277

# %%
df.loc[(df.conc == 0) & (df.lambd == pd.NA) & (df.temp == 300)]
# Out:
# Empty DataFrame
# Columns: [protein, small_molec, conc, lambd, sigma, temp, idp_average, drg_average, hash, extension, sim_time, time_unit, idp_plat_avg, drg_plat_avg, idp_dilu_avg, drg_dilu_avg]
# Index: []

# %% [markdown]
# ## Plot Curve Graphs from DB

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rc("font", family="serif")
plt.rcParams.update({"font.size": 25})
plt.rcParams["axes.linewidth"] = 0.6

# Figure 9
#q1 = df[df.lambd == 0][df.conc == 20.0][df.temp == 323.0][df.sigma == 0.45]
#q2 = df[df.lambd == 0][df.conc == 2.0][df.temp == 323.0][df.sigma == 0.97]
#q3 = df[df.lambd == 0][df.conc == 0.2][df.temp == 323.0][df.sigma == 2.099]
#q3 = df[df.lambd == 0][df.conc == 0.2][df.temp == 323.0][df.sigma == 2.099]
#q4 = df[df.sigma == 4.500]

# Figure 6
q1 = df[df.lambd == 0][df.temp == 323][df.conc == 2][df.sigma == 0.45]
q2 = df[df.lambd == 0][df.temp == 323][df.conc == 0.2][df.sigma == 0.45]
q3 = df[df.lambd == 0][df.conc == 10][df.temp == 323.0][df.sigma == 0.45]
q4 = df[df.lambd == 0][df.conc == 20][df.temp == 323.0][df.sigma == 0.45]
query = pd.concat([q1,q2,q3,q4],ignore_index=True)


# Figure 7
#q1 = df[df.lambd == 0][df.temp == 323][df.conc == 20][df.sigma == 0.45]
#q2 = df[df.lambd == 0.175][df.temp == 323][df.conc == 20][df.sigma == 0.45]
#q3 = df[df.lambd == 0.350][df.temp == 323][df.conc == 20][df.sigma == 0.45]
#q4 = df[df.lambd == 0.525][df.temp == 323][df.conc == 20][df.sigma == 0.45]
#q5 = df[df.lambd == 0.7][df.temp == 323][df.conc == 20][df.sigma == 0.45]
#q6 = df[df.lambd == 0.9][df.temp == 323][df.conc == 20][df.sigma == 0.45]
#query = pd.concat([q1,q2,q3,q4,q5,q6],ignore_index=True)


# plotting inset for Figure 7
#x = nodrg_avg[:,0]
# y = nodrg_avg[:,1]
#y = list_vals_NONE
#cnt = 75
#x_reg = x[cnt-(cnt//7) : (cnt+(cnt//7))]
#y_reg = y[cnt-(cnt//7):cnt+(cnt//7)]

#ax3.plot(x_reg, y_reg, color='pink', lw=4, ls=':')


display(query)

# Viridis
# Figure 6: winter
# Figure 7: plasma
col_arr = plt.cycler("color", plt.cm.winter(np.linspace(0, 1, len(query['idp_average']))))

fig, (ax1, ax2) = plt.subplots(ncols=2)
fig.set_size_inches(12, 6)

# Inset for figure 6
from mpl_toolkits.axes_grid.inset_locator import (inset_axes, InsetPosition, mark_inset)

# Create a set of inset Axes: these should fill the bounding box allocated to
# them.
ax3 = plt.axes([0,0,1,1])

# Manually set the position and relative size of the inset axes within ax1
ip = InsetPosition(ax1, [0.75,0.5,0.25,0.25])
ax3.set_axes_locator(ip)

# Mark the region corresponding to the inset axes on ax1 and draw lines
# in grey linking the two axes.
mark_inset(ax1, ax3, loc1=1, loc2=3, fc="none", ec='0.5')


for ind, row in enumerate(zip(query['idp_average'],query['drg_average'])):
    row_values = query.iloc[[ind]]
    temp = float(row_values.temp)
    lamb = float(row_values.lambd)
    sig = float(row_values.sigma)
    conc = float(row_values.conc)
    col_val = np.array(col_arr)[ind]['color']
    
    
    # Converting the particle count to concentration
    # total cell volume in L: 3.375e-20
    # volume of the condensed phase: 4.275e-21
    bin_vol = 1e3*15e-9*15e-9*1e-9
    
    list_vals_idp = []
    for z, val in zip(row[0][:,0],row[0][:,1]):
        list_vals_idp.append(val * (1/6.02e23) * (1/bin_vol) * 1000 * (1/167))
    
    list_vals_drg = []
    for z, val in zip(row[1][:,0],row[1][:,1]):
        list_vals_drg.append(val * (1/6.02e23) * (1/bin_vol) * 1000)
    #print(sum(list_vals))
        
    y_reg2 = list_vals_idp[cnt-(cnt//7):cnt+(cnt//7)]    
    
    ax1.plot(row[0][:,0],list_vals_idp, label=f'{temp}K {lamb} {sig} {conc}mM', color=col_val, lw=4)
    ax2.plot(row[1][:,0],list_vals_drg, label=f'GLY {temp}K {lamb} {sig} {conc}mM', color=col_val, lw=4)
    ax3.plot(x_reg,y_reg2, label=f'{temp}K NODRG', color=col_val, lw=4,)
    #ax1.plot(row[0][:,0],row[0][:,1], label=f'{temp}K {lamb} {sig} {conc}mM', color=col_val, lw=4)
    #ax2.plot(row[1][:,0],row[1][:,1], label=f'GLY {temp}K {lamb} {sig} {conc}mM', color=col_val, lw=4)
    
    
    #plotting inset for Figure 6
    x = row[0][:,0]
    #y = row[0][:,1]
    y = list_vals_idp
    #cnt = 75
    x_reg = x[cnt-(cnt//7) : (cnt+(cnt//7))]
    y_reg = y[cnt-(cnt//7):cnt+(cnt//7)]
    ax3.plot(x_reg, y_reg, color=col_val, lw=4)
    

# Figure 7: Plotting 323K NODRG
#q7 = df[df.small_molec != "GLY"][df.temp == 323]
#nodrg_avg = (q7['idp_average'].values[0])
#z = nodrg_avg[:,0]
#list_vals_NONE = []
#for z, val in zip(nodrg_avg[:,0],nodrg_avg[:,1]):
#    list_vals_NONE.append(val * (1/6.02e23) * (1/bin_vol) * 1000 * (1/167))
# print(nodrg_avg)
#ax1.plot(nodrg_avg[:,0],list_vals_NONE, label=f'{temp}K NODRG', color='pink', lw=4, ls=':')

# plotting inset for Figure 7
#x = nodrg_avg[:,0]
# y = nodrg_avg[:,1]
#y = list_vals_NONE
#cnt = 75
#x_reg = x[cnt-(cnt//7) : (cnt+(cnt//7))]
#y_reg = y[cnt-(cnt//7):cnt+(cnt//7)]
#y_reg2 = list_vals_idp[cnt-(cnt//7):cnt+(cnt//7)]
#ax3.plot(x_reg, y_reg, color='pink', lw=4, ls=':')
#ax3.plot(x_reg,y_reg2, label=f'{temp}K NODRG', color='orange', lw=4, ls=':')

    
ax1.legend(
        loc="lower left",
        fontsize=12.5,
        handlelength=1,
        labelspacing=0.7,
)



ax1.set_xlabel("z", fontsize=25)
ax1.set_ylabel("Average Conc. (mM)", fontsize=25)
ax2.set_xlabel("z", fontsize=25)
ax2.set_ylabel("Average Conc. (mM)", fontsize=25)
ax1.tick_params(labelsize=25)
ax2.tick_params(labelsize=25)
ax1.set_xticks([0, 75, 150],[0, 75, 150])
ax2.set_xticks([0, 75, 150],[0, 75, 150])

plt.tight_layout()

# Change number according to figure
#plt.savefig(f'plot_7_updated.svg',dpi=500)
plt.savefig(f'plot_6_updated.svg',dpi=500)

plt.show()
# Out:
# /tmp/ipykernel_25477/2969663618.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   q1 = df[df.lambd == 0][df.temp == 323][df.conc == 2][df.sigma == 0.45]
# /tmp/ipykernel_25477/2969663618.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   q2 = df[df.lambd == 0][df.temp == 323][df.conc == 0.2][df.sigma == 0.45]
# /tmp/ipykernel_25477/2969663618.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   q3 = df[df.lambd == 0][df.conc == 10][df.temp == 323.0][df.sigma == 0.45]
# /tmp/ipykernel_25477/2969663618.py:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   q4 = df[df.lambd == 0][df.conc == 20][df.temp == 323.0][df.sigma == 0.45]
#    protein small_molec  conc  lambd  sigma   temp  \
# 0  Q5-8_20         GLY   2.0    0.0   0.45  323.0
# 1  Q5-8_20         GLY   0.2    0.0   0.45  323.0
# 2  Q5-8_20         GLY  10.0    0.0   0.45  323.0
# ...

# %% [markdown]
# ## Linear Temperature graph

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

TEMPS = [
    270, 290, 300,
    310, 315, 320,
    323, 330, 340,
    350, #370, 375, 
    #380, 385, 390
]

# importing pandas
import pandas as pd
 
# reading pickle
df = pd.read_pickle('simulations_df.pkl')

prop_avg = []
for T in TEMPS:
    avg_val = df.loc[(df.small_molec != "GLY") & (df.temp == T)].idp_plat_avg.values
    if len(avg_val) > 0:
        prop_avg.append(avg_val[0])
    else:
        prop_avg.append(None)
    


mark = "o"
label_text = f"{T}K"

for T_pos, T in enumerate(TEMPS):
    col = choose_cmap_color(
        T, "temp", ["Q5"], ["GLY"], CONC, TEMPS, LAMBDAS
    )

    # Converting the particle count to concentration
    # total cell volume in L: 3.375e-20
    # volume of the condensed phase: 4.275e-21
    # bin volume: 1e3*15e-9*15e-9*1e-9

    bin_vol = 1e3*15e-9*15e-9*1e-9
    x_conc = prop_avg[T_pos] * (1/6.02e23) * (1/bin_vol) * 1000 * (1/167)  
    
    label_text = f"{T}K"
    plt.plot(
        # prop_avg[T_pos]
        x_conc,
        TEMPS[T_pos],
        markersize=18,
        marker=mark,
        linestyle="-",
        color=col,
        label=label_text,
        # zorder=0,
    )

plt.rc("font", family="serif")
plt.rcParams.update({"font.size": 25})
plt.rcParams["axes.linewidth"] = 0.5
plt.xlabel("Average density",fontsize=25)
plt.legend(
    framealpha=0,
    fontsize=25,
    # bbox_to_anchor=(0, 1, 1, 0),
    ncol=3,
    mode="expand",
    markerscale=0.8,
)
plt.ylabel("Temperature (K)", fontsize=25)


# Checking if there is any "None" value in the average list (if the
# simulation has not been performed)
prop_avg = np.array(prop_avg)
mask = pd.isnull(prop_avg)
prop_avg = (prop_avg[~mask])
T_masked = (np.array(TEMPS)[~mask])

x_conc_full = prop_avg * (1/6.02e23) * (1/bin_vol) * 1000 * (1/167) 

plt.plot(
    x_conc_full,
    T_masked,
    # markersize=10,
    # marker=mark,
    linestyle=":",
    color="grey",
    label=label_text,
    zorder=0,
)


plt.rcParams.update({"font.size": 25})
plt.rc("font", family="serif")
plt.tick_params(labelsize=25)


plt.savefig(
    f"plot_temp_lines_updated_conc.svg",
    # transparent=True,
    dpi=500,
    bbox_inches="tight",
)


plt.tight_layout()
plt.show()
# Out:
# conc: [20.0]
# value:  270
# conc: [20.0]
# value:  290
# conc: [20.0]
# value:  300
# conc: [20.0]
# value:  310
# conc: [20.0]
# value:  315
# conc: [20.0]
# value:  320
# conc: [20.0]
# value:  323
# conc: [20.0]
# value:  330
# conc: [20.0]
# value:  340
# conc: [20.0]
# value:  350

# %% [markdown]
# # Figure 9

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
import itertools


# importing pandas
import pandas as pd
 
# reading pickle
df = pd.read_pickle('simulations_df.pkl')
 
# set the max columns to none
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

#print(df.shape)
#display(df)

def choose_cmap_color(value, prop, PROTEINS, DRUGS, CONC, TEMPS, LAMBDAS):

    # TEMPS = [290, 300, 310, 315, 320, 323, 325, 330]
    # LAMBDAS = ["None", 0.0, 0.175, 0.35, 0.525, 0.7]
    # CONC = [0.2, 2.0, 10, 20.0]
    print("conc:", CONC)

    if prop in ["temperature", "T", "temp", "t"]:
        col_arr = plt.cycler("color", plt.cm.viridis(np.linspace(0, 1, len(TEMPS))))
        col_val = np.array(col_arr)[TEMPS.index(value)]
        print("value: ", value)

    elif prop in ["lambda", "l", "lam", "lamb"]:
        # default plasma
        # cool in the YRD presentation
        col_arr = plt.cycler("color", plt.cm.plasma(np.linspace(0, 1, len(LAMBDAS))))
        col_val = np.array(col_arr)[LAMBDAS.index(value)]

    elif prop in ["conc", "c", "conc"]:
        col_arr = plt.cycler("color", plt.cm.winter(np.linspace(0, 1, len(CONC))))
        col_val = np.array(col_arr)[CONC.index(value)]

    elif prop in ["both"]:
        combin = list(itertools.product(TEMPS, LAMBDAS))
        # print("combin: ", combin)
        col_arr = plt.cycler("color", plt.cm.magma(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    elif prop in ["conc_temp"]:
        combin = list(itertools.product(TEMPS, CONC))
        col_arr = plt.cycler("color", plt.cm.cool(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    elif prop in ["conc_lambda", "lambda_conc"]:
        combin = list(itertools.product(LAMBDAS, CONC))
        print("combin: ", combin)
        print(value)
        col_arr = plt.cycler("color", plt.cm.viridis(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    elif prop in ["all", "conc_lambda_temp"]:
        combin = list(itertools.product(TEMPS, LAMBDAS, CONC))
        col_arr = plt.cycler("color", plt.cm.prism(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    return col_val["color"]


def plot_averages(type):

    # combin_all = itertools.product(CONC, TEMPS, LAMBDAS)
    # for comb in combin_all:
    #     prop_dict_T[comb[0]][comb[1]][comb[2]]
    #     print('prop_dict_T[comb[0]][comb[1]][comb[2]]: ', prop_dict_T[comb[0]][comb[1]][comb[2]])
    #     # prop_avg.append(prop_dict_T[20][T][lamb])
    # print('combin: ', list(combin))
    # quit()

    # combin = list(itertools.product(LAMBDAS, CONC))

    for cc in CONC:
        #print("\ncc: ", cc)
        for lamb in LAMBDAS:
            prop_avg = []
            #print("lamb: ", lamb)
            for T in TEMPS:
                entry = df.loc[(df.conc == cc) & (df.lambd == lamb) & (df.temp == T) & (df.sigma == 0.450)]
                if type == "idp":
                    try:
                        # print("entry.idp_average: ", entry.idp_plat_avg.values[0])
                        prop_avg.append(entry.idp_plat_avg.values[0])
                        #print("T: ", T, "avg", entry.idp_plat_avg.values[0])
                    except IndexError:
                        prop_avg.append(None)
                elif type == "drg":
                    try:
                        # print("entry.idp_average: ", entry.idp_plat_avg.values[0])
                        prop_avg.append(entry.drg_plat_avg.values[0])
                    except IndexError:
                        prop_avg.append(None)

            # prop_avg = []

            col = choose_cmap_color(
                lamb, "lambda", ["Q5"], ["GLY"], CONC, TEMPS, LAMBDAS
            )

            if cc == 10.0:
                mark = "^"
            elif cc == 15.0:
                mark = "P"
            elif cc == 20.0:
                mark = "o"
            else:
                mark = "o"

            if type == "idp":
                label_text = f"$\\lambda$ = {lamb}\n{cc}mM"
            elif type == "drg":
                label_text = f"$\\lambda$ = {lamb}\n{cc}mM"

                
            # Checking if there is any "None" value in the average list (if the
            # simulation has not been performed)
            prop_avg = np.array(prop_avg)
            mask = pd.isnull(prop_avg)
            prop_avg = (prop_avg[~mask])
            T_masked = (np.array(TEMPS)[~mask])
            
            # Converting the particle count to concentration
            # total cell volume in L: 3.375e-20
            # volume of the condensed phase: 4.275e-21
            # volume of the dilute phase: 2,9475e-20
            bin_vol = 1e3*15e-9*15e-9*1e-9
            x_conc = prop_avg * (1/6.02e23) * (1/bin_vol) * 1000
            
            #print("temp",T,"prop_avg: ", prop_avg)
            plt.plot(
                x_conc,
                T_masked,
                markersize=20,
                marker=mark,
                linestyle=":",
                lw=5,
                color=col,
                label=label_text,
            )

    #l_315_avg = [578.850105263158, 1.7949473684210526]
    #l_323_avg = [536.6486315789474, 1.8348070175438598]
    #l_315_ext = [581.0241754385966, 1.7608070175438597]

    #plt.plot(l_315_avg[0], 323, "s", color="red", label=r"$0.350\ 315K \rightarrow 323K$")
    #plt.plot(l_315_ext[0], 315, "s", color="magenta", label="0.350 315K extended")
    #plt.plot(l_323_avg[0], 315, "s", color="blue", label=r"$0.350\ 323K \rightarrow 315K$")

    #nodrg_entries = df[df.small_molec != 'GLY'][df.temp < 370]
    #plt.plot(
    #    nodrg_entries.idp_plat_avg,
    #    nodrg_entries.temp,
    #    markersize=14,
    #    marker='o',
    #    linestyle="None",
    #    lw=5,
    #    color='cyan',
    #    label='NODRG',
    #    alpha=0.7,
    #    markeredgewidth=1.5,
    #    mec='black',
        #path_effects=[pe.Stroke(linewidth=1, foreground='black')],
    #)

    plt.xlabel("Average concentration (mM)", fontsize=25)
    plt.legend(
        framealpha=0,
        fontsize=13,
        bbox_to_anchor=(0, 1, 1, 0),
        ncol=3,
        mode="expand",
        markerscale=0.8,
    )
    plt.ylabel("Temperature (K)", fontsize=25)
    # plt.yticks(
    #     [270, 280, 290, 300, 310, 320, 330, 340, 350],
    #     [270, 280, 290, 300, 310, 320, 330, 340, 350],
    # )
    #plt.grid()
    plt.tight_layout()
    # plt.subplots_adjust(top=.95)
    # plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=5, hspace=5)
    # plt.show()
    # plt.savefig(
    #     f"testT_phasediag_DRG_all_lambda-temps_all.png",
    #     transparent=True,
    #     dpi=400,
    #     bbox_inches="tight",
    # )
    #plt.savefig("alllambdas_drg_concentration.svg",dpi=500)
    plt.show()


TEMPS = [
    270,
    290,
    300,
    310,
    315,
    320,
    323,
    330,
    340,
    350,
    #370
]
LAMBDAS = [
    0,
    #-0.1,
    0.175,
    0.350,
    0.525,
    0.7,
    0.9,
    # "None",
    # None,
]
CONC = [
    # 0.0,
    # None,
    # 0.2,
    # 2.0,
    # 10.0,
    # 15.0,
    20.0,
]

#hash_del_list = []

#for hash_id in hash_del_list:
    #print(hash_id)
    #print(df.index[df['hash'] == hash_id])
 #   ind = df.index[df['hash'] == hash_id][0]
 #   df.drop(ind, inplace=True)

#db_path = ("simulations_df.pkl")
#df = df.drop(index=84)
#df = df.drop(index=86)
#df = df.drop(index=91)
#df = df.drop(index=134)
#df = df.drop(index=92)
#df = df.drop(index=132)
# df = pd.read_pickle(db_path)

# display(df[df.small_molec == None].sort_values('temp', axis=0))

plt.rc("font", family="serif")
plt.rcParams.update({"font.size": 25})
plt.tick_params(labelsize=25)
plt.rcParams["axes.linewidth"] = 0.5
plt.style.use("seaborn-poster")

plot_averages(type="drg")
# Out:
# conc: [20.0]
# conc: [20.0]
# conc: [20.0]
# conc: [20.0]
# conc: [20.0]
# conc: [20.0]

# %% [markdown]
# # Figure 10

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rc("font", family="serif")
plt.rcParams.update({"font.size": 25})
plt.rcParams["axes.linewidth"] = 0.6

# Figure 9
q1 = df[df.lambd == 0][df.conc == 20.0][df.temp == 323.0][df.sigma == 0.45]
q2 = df[df.lambd == 0][df.conc == 2.0][df.temp == 323.0][df.sigma == 0.97]
q3 = df[df.lambd == 0][df.conc == 0.2][df.temp == 323.0][df.sigma == 2.099]
q3 = df[df.lambd == 0][df.conc == 0.2][df.temp == 323.0][df.sigma == 2.099]
query = pd.concat([q1,q2,q3],ignore_index=True)


display(query)

# Viridis
# Figure 6: winter
# Figure 7: plasma
# Figure 9: viridis
col_arr = plt.cycler("color", plt.cm.viridis(np.linspace(0, 1, len(query['idp_average']))))

fig, (ax1, ax2) = plt.subplots(ncols=2)
fig.set_size_inches(12, 6)

bin_vol = 1e3*15e-9*15e-9*1e-9

for ind, row in enumerate(zip(query['idp_average'],query['drg_average'])):
    row_values = query.iloc[[ind]]
    temp = float(row_values.temp)
    lamb = float(row_values.lambd)
    sig = float(row_values.sigma)
    conc = float(row_values.conc)
    col_val = np.array(col_arr)[ind]['color']
    
    
    # Converting the particle count to concentration
    # total cell volume in L: 3.375e-20
    # volume of the condensed phase: 4.275e-21
    
    
    list_vals_idp = []
    for z, val in zip(row[0][:,0],row[0][:,1]):
        list_vals_idp.append(val * (1/6.02e23) * (1/bin_vol) * 1000 * (1/167))
    
    list_vals_drg = []
    for z, val in zip(row[1][:,0],row[1][:,1]):
        list_vals_drg.append(val * (1/6.02e23) * (1/bin_vol) * 1000)
    
    ax1.plot(row[0][:,0],list_vals_idp, label=f'{temp}K {lamb} {sig} {conc}mM', color=col_val, lw=4)
    ax2.plot(row[1][:,0],list_vals_drg, label=f'GLY {temp}K {lamb} {sig} {conc}mM', color=col_val, lw=4)
       
    #ax1.plot(row[0][:,0],row[0][:,1], label=f'{temp}K {lamb} {sig} {conc}mM', color=col_val, lw=4)
    #ax2.plot(row[1][:,0],row[1][:,1], label=f'GLY {temp}K {lamb} {sig} {conc}mM', color=col_val, lw=4)


# Figure 9: Plotting sigma=4.5
q4 = df[df.sigma == 4.500]
prot_avg = (q4['idp_average'].values[0])
drg_avg = (q4['drg_average'].values[0])

list_vals_large_idp = []
for z, val in zip(prot_avg[:,0],prot_avg[:,1]):
    list_vals_large_idp.append(val * (1/6.02e23) * (1/bin_vol) * 1000 * (1/167))

list_vals_large_drg = []
for z, val in zip(drg_avg[:,0],drg_avg[:,1]):
    list_vals_large_drg.append(val * (1/6.02e23) * (1/bin_vol) * 1000)
    
    
# print(nodrg_avg)
ax1.plot(prot_avg[:,0],list_vals_large_idp, label=f'{temp}K s=4.5 l=0 20mM', color='orange', lw=4, ls=':')
ax2.plot(drg_avg[:,0],list_vals_large_drg, label=f'{temp}K s=4.5 l=0 20mM', color='orange', lw=4, ls=':')


#ax1.plot(nodrg_avg[:,0],list_vals_NONE, label=f'{temp}K NODRG', color='pink', lw=4, ls=':')

    
ax1.legend(
        loc="lower left",
        fontsize=12.5,
        handlelength=1,
        labelspacing=0.7,
)



ax1.set_xlabel("z", fontsize=25)
ax1.set_ylabel("Average Density", fontsize=25)
ax2.set_xlabel("z", fontsize=25)
ax2.set_ylabel("Average Density", fontsize=25)
ax1.tick_params(labelsize=25)
ax2.tick_params(labelsize=25)


plt.tight_layout()

# Change number according to figure
plt.savefig(f'plot_9_concentration.svg',dpi=500)

plt.show()
# Out:
# /tmp/ipykernel_25477/4263500446.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   q1 = df[df.lambd == 0][df.conc == 20.0][df.temp == 323.0][df.sigma == 0.45]
# /tmp/ipykernel_25477/4263500446.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   q2 = df[df.lambd == 0][df.conc == 2.0][df.temp == 323.0][df.sigma == 0.97]
# /tmp/ipykernel_25477/4263500446.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   q3 = df[df.lambd == 0][df.conc == 0.2][df.temp == 323.0][df.sigma == 2.099]
# /tmp/ipykernel_25477/4263500446.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   q3 = df[df.lambd == 0][df.conc == 0.2][df.temp == 323.0][df.sigma == 2.099]
#    protein small_molec  conc  lambd  sigma   temp  \
# 0  Q5-8_20         GLY  20.0    0.0  0.450  323.0
# 1  Q5-8_20         GLY   2.0    0.0  0.970  323.0
# 2  Q5-8_20         GLY   0.2    0.0  2.099  323.0
#
# ...

# %% [markdown]
# # Phase Diagram

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

TEMPS = [
    270, 290, 300,
    310, 315, 320,
    323, 330, 340,
    350, 370, 375, 
    #380, 385, 390
]

# importing pandas
import pandas as pd
 
# reading pickle
df = pd.read_pickle('simulations_df.pkl')

prop_avg = []
for T in TEMPS:
    avg_val = df.loc[(df.small_molec != "GLY") & (df.temp == T)].idp_plat_avg.values
    if len(avg_val) > 0:
        prop_avg.append(avg_val[0])
    else:
        prop_avg.append(None)
    


mark = "o"
label_text = f"{T}K"

for T_pos, T in enumerate(TEMPS):
    col = choose_cmap_color(
        T, "temp", ["Q5"], ["GLY"], CONC, TEMPS, LAMBDAS
    )

    label_text = f"{T}K"
    plt.plot(
        prop_avg[T_pos],
        TEMPS[T_pos],
        markersize=18,
        marker=mark,
        linestyle="-",
        color=col,
        label=label_text,
        # zorder=0,
    )

plt.rc("font", family="serif")
plt.rcParams.update({"font.size": 25})
plt.rcParams["axes.linewidth"] = 0.5
plt.xlabel("Average density",fontsize=25)
plt.legend(
    framealpha=0,
    fontsize=25,
    # bbox_to_anchor=(0, 1, 1, 0),
    ncol=3,
    mode="expand",
    markerscale=0.8,
)
plt.ylabel("Temperature (K)", fontsize=25)
    
plt.plot(
    prop_avg,
    TEMPS,
    # markersize=10,
    # marker=mark,
    linestyle=":",
    color="grey",
    label=label_text,
    zorder=0,
)


plt.rcParams.update({"font.size": 25})
plt.rc("font", family="serif")
plt.tick_params(labelsize=25)


#plt.savefig(
#    f"plot_temp_lines_updated.svg",
    # transparent=True,
#    dpi=500,
#    bbox_inches="tight",
#)


plt.tight_layout()
plt.show()

# %% [markdown]
# # Figure 9 Alt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
import itertools
import sys


# importing pandas
import pandas as pd
 
# reading pickle
df = pd.read_pickle('simulations_df.pkl')
 
# set the max columns to none
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

#print(df.shape)
#display(df)

def choose_cmap_color(value, prop, PROTEINS, DRUGS, CONC, TEMPS, LAMBDAS):

    # TEMPS = [290, 300, 310, 315, 320, 323, 325, 330]
    # LAMBDAS = ["None", 0.0, 0.175, 0.35, 0.525, 0.7]
    # CONC = [0.2, 2.0, 10, 20.0]
    print("conc:", CONC)

    if prop in ["temperature", "T", "temp", "t"]:
        col_arr = plt.cycler("color", plt.cm.viridis(np.linspace(0, 1, len(TEMPS))))
        col_val = np.array(col_arr)[TEMPS.index(value)]
        print("value: ", value)

    elif prop in ["lambda", "l", "lam", "lamb"]:
        # default plasma
        # cool in the YRD presentation
        col_arr = plt.cycler("color", plt.cm.plasma(np.linspace(0, 1, len(LAMBDAS))))
        col_val = np.array(col_arr)[LAMBDAS.index(value)]

    elif prop in ["conc", "c", "conc"]:
        col_arr = plt.cycler("color", plt.cm.winter(np.linspace(0, 1, len(CONC))))
        col_val = np.array(col_arr)[CONC.index(value)]

    elif prop in ["both"]:
        combin = list(itertools.product(TEMPS, LAMBDAS))
        # print("combin: ", combin)
        col_arr = plt.cycler("color", plt.cm.magma(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    elif prop in ["conc_temp"]:
        combin = list(itertools.product(TEMPS, CONC))
        col_arr = plt.cycler("color", plt.cm.cool(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    elif prop in ["conc_lambda", "lambda_conc"]:
        combin = list(itertools.product(LAMBDAS, CONC))
        print("combin: ", combin)
        print(value)
        col_arr = plt.cycler("color", plt.cm.viridis(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    elif prop in ["all", "conc_lambda_temp"]:
        combin = list(itertools.product(TEMPS, LAMBDAS, CONC))
        col_arr = plt.cycler("color", plt.cm.prism(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    return col_val["color"]


def plot_averages(type):

    for cc in CONC:
        for lamb in LAMBDAS:
            prop_avg = []
            dilu_avg = []
            #print("lamb: ", lamb)
            for T in TEMPS:
                entry = df.loc[(df.conc == cc) & (df.lambd == lamb) & (df.temp == T) & (df.sigma == 0.450)]
                if type == "idp":
                    try:
                        # print("entry.idp_average: ", entry.idp_plat_avg.values[0])
                        prop_avg.append(entry.idp_plat_avg.values[0])
                        #print("T: ", T, "avg", entry.idp_plat_avg.values[0])
                    except IndexError:
                        prop_avg.append(None)
                elif type == "drg":
                    try:
                        # print("entry.idp_average: ", entry.idp_plat_avg.values[0])
                        prop_avg.append(entry.drg_plat_avg.values[0])
                        dilu_avg.append(entry.drg_dilu_avg.values[0])
                    except IndexError:
                        prop_avg.append(None)
                        dilu_avg.append(None)

            # prop_avg = []

            col = choose_cmap_color(
                lamb, "lambda", ["Q5"], ["GLY"], CONC, TEMPS, LAMBDAS
            )

            if cc == 10.0:
                mark = "^"
            elif cc == 15.0:
                mark = "P"
            elif cc == 20.0:
                mark = "o"
            else:
                mark = "o"

            if type == "idp":
                label_text = f"$\\lambda$ = {lamb}\n{cc}mM"
            elif type == "drg":
                label_text = f"$\\lambda$ = {lamb}\n{cc}mM"

            prop_avg = np.array(prop_avg)
            dilu_avg = np.array(dilu_avg)
            
            print(f"For lambda = {lamb}")
            for con, dil, T in zip(prop_avg, dilu_avg, TEMPS):
                if con and dil:
                    #print(con, dil)
                    ratio = (float(con)/float(dil))
                    print(f"{T}K: {ratio}")
            #print(np.array(prop_avg)/np.array(dilu_avg))
            
            #test = prop_avg/dilu_avg
            #print(test)

            # Checking if there is any "None" value in the average list (if the
            # simulation has not been performed)
            prop_avg = np.array(prop_avg)
            mask = pd.isnull(prop_avg)
            prop_avg = (prop_avg[~mask])
            
            dilu_avg = np.array(dilu_avg)
            mask = pd.isnull(dilu_avg)
            dilu_avg = (dilu_avg[~mask])
            
            T_masked = (np.array(TEMPS)[~mask])
            
            # Converting the particle count to concentration
            # total cell volume in L: 3.375e-20
            # volume of the condensed phase: 4.275e-21
            # volume of the dilute phase: 2,9475e-20
            bin_vol = 1e3*15e-9*15e-9*1e-9
            x_conc = prop_avg * (1/6.02e23) * (1/bin_vol) * 1000
            x_conc_dilu = dilu_avg * (1/6.02e23) * (1/bin_vol) * 1000
            
            
            plt.plot(
                x_conc,
                T_masked,
                markersize=20,
                marker=mark,
                linestyle=":",
                lw=5,
                color=col,
                label=label_text,
            )
            
            plt.plot(
                x_conc_dilu,
                T_masked,
                markersize=20,
                marker='P',
                linestyle=":",
                lw=5,
                color=col,
                label=label_text,
            )

            


    plt.xlabel("Average concentration (mM)", fontsize=25)
    plt.legend(
        framealpha=0,
        fontsize=13,
        bbox_to_anchor=(0, 1, 1, 0),
        ncol=3,
        mode="expand",
        markerscale=0.8,
    )
    plt.ylabel("Temperature (K)", fontsize=25)
    plt.tight_layout()

    plt.savefig("test_alllambdas_drg_alt_conc.svg",dpi=500)
    plt.show()


TEMPS = [
    270,
    290,
    300,
    310,
    315,
    320,
    323,
    330,
    340,
    350,
    #370
]
LAMBDAS = [
    #-0.7,
    #-0.1,
    0,
    0.175,
    0.350,
    0.525,
    0.7,
    0.9,
    # "None",
    # None,
]
CONC = [
    # 0.0,
    # None,
    # 0.2,
    # 2.0,
    # 10.0,
    # 15.0,
    20.0,
]

plt.rc("font", family="serif")
plt.rcParams.update({"font.size": 25})
plt.tick_params(labelsize=25)
plt.rcParams["axes.linewidth"] = 0.5
plt.style.use("seaborn-poster")

plot_averages(type="drg")
# Out:
# conc: [20.0]
# For lambda = 0
# 270K: 0.3506112013001869
# 290K: 0.4075271576836637
# 300K: 0.4431901713105568
# 310K: 0.4872981058466
# 315K: 0.5025769281633085
# 323K: 0.5554905554048996
# 330K: 0.5944002668071872
# 340K: 0.6583914484300765
# 350K: 0.7358549679324968
# conc: [20.0]
# For lambda = 0.175
# 270K: 0.4144835516794547
# 290K: 0.4774136246326679
# 300K: 0.4966951704075084
# 310K: 0.5330209990537079
# 315K: 0.5636483564115731
# 320K: 0.5848867897636517
# 323K: 0.6012001385452802
# 330K: 0.6261214222827748
# 340K: 0.684859215801168
# 350K: 0.7737856840725673
# conc: [20.0]
# For lambda = 0.35
# 270K: 0.49890312932482134
# 290K: 0.5344281446544423
# 300K: 0.5641040088584895
# 310K: 0.5877529337311616
# 315K: 0.6193258870700168
# 320K: 0.6381509234209756
# 323K: 0.6424733425286515
# 330K: 0.6876856362124272
# 340K: 0.7410930714093642
# 350K: 0.8145851777614801
# conc: [20.0]
# For lambda = 0.525
# 270K: 0.5876477691572177
# 290K: 0.6216987037533644
# 300K: 0.6525168507098811
# ...

# %% [markdown]
# # Fig 10 alt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
import itertools


# importing pandas
import pandas as pd
 
# reading pickle
df = pd.read_pickle('simulations_df.pkl')
 
# set the max columns to none
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

#print(df.shape)
#display(df)

def choose_cmap_color(value, prop, PROTEINS, DRUGS, CONC, TEMPS, LAMBDAS):

    # TEMPS = [290, 300, 310, 315, 320, 323, 325, 330]
    # LAMBDAS = ["None", 0.0, 0.175, 0.35, 0.525, 0.7]
    # CONC = [0.2, 2.0, 10, 20.0]
    print("conc:", CONC)

    if prop in ["temperature", "T", "temp", "t"]:
        col_arr = plt.cycler("color", plt.cm.viridis(np.linspace(0, 1, len(TEMPS))))
        col_val = np.array(col_arr)[TEMPS.index(value)]
        print("value: ", value)

    elif prop in ["lambda", "l", "lam", "lamb"]:
        # default plasma
        # cool in the YRD presentation
        col_arr = plt.cycler("color", plt.cm.plasma(np.linspace(0, 1, len(LAMBDAS))))
        col_val = np.array(col_arr)[LAMBDAS.index(value)]

    elif prop in ["conc", "c", "conc"]:
        col_arr = plt.cycler("color", plt.cm.winter(np.linspace(0, 1, len(CONC))))
        col_val = np.array(col_arr)[CONC.index(value)]

    elif prop in ["both"]:
        combin = list(itertools.product(TEMPS, LAMBDAS))
        # print("combin: ", combin)
        col_arr = plt.cycler("color", plt.cm.magma(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    elif prop in ["conc_temp"]:
        combin = list(itertools.product(TEMPS, CONC))
        col_arr = plt.cycler("color", plt.cm.cool(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    elif prop in ["conc_lambda", "lambda_conc"]:
        combin = list(itertools.product(LAMBDAS, CONC))
        print("combin: ", combin)
        print(value)
        col_arr = plt.cycler("color", plt.cm.viridis(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    elif prop in ["all", "conc_lambda_temp"]:
        combin = list(itertools.product(TEMPS, LAMBDAS, CONC))
        col_arr = plt.cycler("color", plt.cm.prism(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    return col_val["color"]


def plot_averages(type):

    # combin_all = itertools.product(CONC, TEMPS, LAMBDAS)
    # for comb in combin_all:
    #     prop_dict_T[comb[0]][comb[1]][comb[2]]
    #     print('prop_dict_T[comb[0]][comb[1]][comb[2]]: ', prop_dict_T[comb[0]][comb[1]][comb[2]])
    #     # prop_avg.append(prop_dict_T[20][T][lamb])
    # print('combin: ', list(combin))
    # quit()

    # combin = list(itertools.product(LAMBDAS, CONC))

    for cc in CONC:
        #print("\ncc: ", cc)
        for lamb in LAMBDAS:
            prop_avg = []
            dilu_avg = []
            #print("lamb: ", lamb)
            for T in TEMPS:
                entry = df.loc[(df.conc == cc) & (df.lambd == lamb) & (df.temp == T) & (df.sigma == 0.450)]
                if type == "idp":
                    try:
                        # print("entry.idp_average: ", entry.idp_plat_avg.values[0])
                        prop_avg.append(entry.idp_plat_avg.values[0])
                        dilu_avg.append(entry.drg_dilu_avg.values[0])
                        #print("T: ", T, "avg", entry.idp_plat_avg.values[0])
                        print(f"{T}K {entry.idp_dilu_avg.values[0]}")
                    except IndexError:
                        prop_avg.append(None)
                        dilu_avg.append(None)
                elif type == "drg":
                    try:
                        prop_avg.append(entry.drg_plat_avg.values[0])
                    except IndexError:
                        prop_avg.append(None)
                        

            # prop_avg = []

            col = choose_cmap_color(
                lamb, "lambda", ["Q5"], ["GLY"], CONC, TEMPS, LAMBDAS
            )

            if cc == 10.0:
                mark = "^"
            elif cc == 15.0:
                mark = "P"
            elif cc == 20.0:
                mark = "o"
            else:
                mark = "o"

            if type == "idp":
                label_text = f"$\\lambda$ = {lamb}\n{cc}mM"
            elif type == "drg":
                label_text = f"$\\lambda$ = {lamb}\n{cc}mM"

            #print("temp",T,"prop_avg: ", prop_avg)
            plt.plot(
                prop_avg,
                TEMPS,
                markersize=20,
                marker=mark,
                linestyle=":",
                lw=5,
                color=col,
                label=label_text,
            )

            plt.plot(
                dilu_avg,
                TEMPS,
                markersize=20,
                marker='P',
                linestyle=":",
                lw=5,
                color=col,
                label=label_text,
            )
            
    
    #l_315_avg = [578.850105263158, 1.7949473684210526]
    #l_323_avg = [536.6486315789474, 1.8348070175438598]
    #l_315_ext = [581.0241754385966, 1.7608070175438597]

    #plt.plot(l_315_avg[0], 323, "s", color="red", label=r"$0.350\ 315K \rightarrow 323K$")
    #plt.plot(l_315_ext[0], 315, "s", color="magenta", label="0.350 315K extended")
    #plt.plot(l_323_avg[0], 315, "s", color="blue", label=r"$0.350\ 323K \rightarrow 315K$")

    nodrg_entries = df[df.small_molec != 'GLY'][df.temp < 370]
    plt.plot(
        nodrg_entries.idp_plat_avg,
        nodrg_entries.temp,
        markersize=14,
        marker='o',
        linestyle="None",
        lw=5,
        color='cyan',
        label='NODRG',
        alpha=0.7,
        markeredgewidth=1.5,
        mec='black',
        #path_effects=[pe.Stroke(linewidth=1, foreground='black')],
    )

    plt.xlabel("Average density", fontsize=25)
    plt.legend(
        framealpha=0,
        fontsize=13,
        bbox_to_anchor=(0, 1, 1, 0),
        ncol=3,
        mode="expand",
        markerscale=0.8,
    )
    plt.ylabel("Temperature (K)", fontsize=25)

    plt.tight_layout()

    #plt.savefig("test_alllambdas.svg",dpi=500)
    plt.show()


TEMPS = [
    270,
    290,
    300,
    310,
    315,
    320,
    323,
    330,
    340,
    350,
    #370
]
LAMBDAS = [
    0,
    #-0.1,
    0.175,
    0.350,
    0.525,
    0.7,
    0.9,
    # "None",
    # None,
]
CONC = [
    # 0.0,
    # None,
    # 0.2,
    # 2.0,
    # 10.0,
    # 15.0,
    20.0,
]


plt.rc("font", family="serif")
plt.rcParams.update({"font.size": 25})
plt.tick_params(labelsize=25)
plt.rcParams["axes.linewidth"] = 0.5
plt.style.use("seaborn-poster")

plot_averages(type="idp")
# Out:
# 270K 17.012707692307693
# 290K 27.493917948717954
# 300K 33.194758974358976
# 310K 39.8276564102564
# 315K 43.420343589743595
# 323K 49.6953076923077
# 330K 55.64646153846154
# 340K 65.36475897435898
# 350K 76.87585128205129
# conc: [20.0]
# 270K 17.130476923076923
# 290K 27.62782564102564
# 300K 33.41514358974359
# 310K 39.930394871794874
# 315K 43.5985076923077
# 320K 47.50110256410257
# 323K 49.702815384615384
# 330K 55.180128205128206
# 340K 64.32661025641025
# 350K 79.02593333333333
# conc: [20.0]
# 270K 17.24854358974359
# 300K 33.792605128205125
# 310K 40.26343076923077
# 315K 43.52527692307692
# 320K 47.41591794871795
# 323K 49.94573846153846
# 330K 55.34346153846153
# 340K 65.613
# 350K 79.16217948717947
# conc: [20.0]
# 270K 17.38048717948718
# 290K 27.674056410256412
# 300K 33.8158923076923
# 310K 40.63617948717949
# 315K 43.96926666666668
# 323K 50.13214358974359
# 330K 55.820564102564106
# 340K 66.03384102564104
# 350K 76.85148205128205
# conc: [20.0]
# ...

# %% [markdown]
# # Density Profile

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rc("font", family="serif")
plt.rcParams.update({"font.size": 25})
plt.rcParams["axes.linewidth"] = 0.6


TEMPS = [
    270, 290, 300,
    310, 315, 320,
    323, 330, 340,
    350, #370, 375, 
    #380, 385, 390
]

query_list = []
for T in TEMPS:
    q1 = df[df.small_molec != 'GLY'][df.temp == T]
    query_list.append(q1)

query = pd.concat(query_list,ignore_index=True)


display(query)

# cmap should be viridis
col_arr = plt.cycler("color", plt.cm.viridis(np.linspace(0, 1, len(query['idp_average']))))

fig.set_size_inches(12, 6)

for ind, row in enumerate(zip(query['idp_average'],query['drg_average'])):
    row_values = query.iloc[[ind]]
    temp = float(row_values.temp)
    lamb = float(row_values.lambd)
    sig = float(row_values.sigma)
    conc = float(row_values.conc)
    col_val = np.array(col_arr)[ind]['color']
       
    plt.plot(row[0][:,0],row[0][:,1], label=f'{temp}K {lamb} {sig} {conc}mM', color=col_val, lw=4)

#plt.legend(
#        loc="lower left",
#        fontsize=12.5,
#        handlelength=1,
#        labelspacing=0.7,
#)


plt.xlabel("z", fontsize=25)
plt.ylabel("Average Density", fontsize=25)
plt.tick_params(labelsize=25)


plt.tight_layout()
plt.savefig(f'idp_standalone_draft.svg',dpi=500)
plt.show()
# Out:
# /tmp/ipykernel_109337/3793742873.py:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   q1 = df[df.small_molec != 'GLY'][df.temp == T]
#    protein small_molec  conc  lambd  sigma   temp  \
# 0  Q5-8_20        None   0.0    NaN    NaN  270.0
# 1  Q5-8_20        None   0.0    NaN    NaN  290.0
# 2  Q5-8_20        None   0.0    NaN    NaN  300.0
# 3  Q5-8_20        None   0.0    NaN    NaN  310.0
# 4  Q5-8_20        None   0.0    NaN    NaN  315.0
# 5  Q5-8_20        None   0.0    NaN    NaN  320.0
# 6  Q5-8_20        None   0.0    NaN    NaN  323.0
# 7  Q5-8_20        None   0.0    NaN    NaN  330.0
# 8  Q5-8_20        None   0.0    NaN    NaN  340.0
# 9  Q5-8_20        None   0.0    NaN    NaN  350.0
#
#                                          idp_average drg_average  \
# 0  [[0.0, 0.0], [1.0, 0.0], [2.0, 0.0], [3.0, 0.0...        None
# 1  [[0.0, 0.0], [1.0, 0.0], [2.0, 0.0], [3.0, 0.0...        None
# ...

# %% [markdown]
# # Average Density vs Particle Volume

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rc("font", family="serif")
plt.rcParams.update({"font.size": 25})
plt.rcParams["axes.linewidth"] = 0.6

# Figure 9
q1 = df[df.lambd == 0][df.conc == 20.0][df.temp == 323.0][df.sigma == 0.45]
q2 = df[df.lambd == 0][df.conc == 2.0][df.temp == 323.0][df.sigma == 0.97]
q3 = df[df.lambd == 0][df.conc == 0.2][df.temp == 323.0][df.sigma == 2.099]
#q3 = df[df.lambd == 0][df.conc == 0.2][df.temp == 323.0][df.sigma == 2.099]
query = pd.concat([q1,q2,q3],ignore_index=True)


display(query)

# Viridis
# Figure 6: winter
# Figure 7: plasma
# Figure 9: viridis
col_arr = plt.cycler("color", plt.cm.viridis(np.linspace(0, 1, len(query['idp_average']))))

#fig, (ax1, ax2) = plt.subplots(ncols=2)
#plt.set_size_inches(12, 6)

SIGMAS = []
AVGS = []

for ind, row in enumerate(zip(query['idp_plat_avg'],query['drg_plat_avg'])):
    row_values = query.iloc[[ind]]
    temp = float(row_values.temp)
    lamb = float(row_values.lambd)
    sig = float(row_values.sigma)
    conc = float(row_values.conc)
    col_val = np.array(col_arr)[ind]['color']
    
    SIGMAS.append(sig)
    AVGS.append(row[0])
    vol = (4 / 3) * np.pi * (sig / 2) ** 3
    plt.scatter(vol,row[0], label=f'{temp}K {lamb} {sig} {conc}mM', color=col_val, lw=4)
    

SIGMAS.append(4.5)
SIGMAS = np.array(SIGMAS)
SIGMAS = (4 / 3) * np.pi * (SIGMAS / 2) ** 3
    

#ax2.scatter(vol,row[1], label=f'GLY {temp}K {lamb} {sig} {conc}mM', color=col_val, lw=4)


# Figure 9: Plotting sigma=4.5
#q4 = df[df.sigma == 4.500]
#prot_avg = (q4['idp_plat_avg'].values[0])
#drg_avg = (q4['drg_plat_avg'].values[0])
#vol = (4 / 3) * np.pi * (4.5 / 2) ** 3
#plt.scatter(vol,prot_avg, label=f'{temp}K s=4.5 l=0 20mM', color='orange', lw=4, marker='x')
#ax2.scatter(vol,drg_avg, label=f'{temp}K s=4.5 l=0 20mM', color='orange', lw=4, ls=':')
    
plt.legend(
        loc="center left",
        fontsize=12.5,
        handlelength=1,
        labelspacing=0.7,
)
plt.xticks(ticks=SIGMAS, labels=SIGMAS)
plt.xscale("log")
plt.xlabel("Particle Volume", fontsize=25)
plt.ylabel("Average Density", fontsize=25)
plt.tick_params(labelsize=25)



plt.tight_layout()

# Change number according to figure
#plt.savefig(f'plot_9.svg',dpi=500)

plt.show()
# Out:
# /tmp/ipykernel_109337/351691951.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   q1 = df[df.lambd == 0][df.conc == 20.0][df.temp == 323.0][df.sigma == 0.45]
# /tmp/ipykernel_109337/351691951.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   q2 = df[df.lambd == 0][df.conc == 2.0][df.temp == 323.0][df.sigma == 0.97]
# /tmp/ipykernel_109337/351691951.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   q3 = df[df.lambd == 0][df.conc == 0.2][df.temp == 323.0][df.sigma == 2.099]
#    protein small_molec  conc  lambd  sigma   temp  \
# 0  Q5-8_20         GLY  20.0    0.0  0.450  323.0
# 1  Q5-8_20         GLY   2.0    0.0  0.970  323.0
# 2  Q5-8_20         GLY   0.2    0.0  2.099  323.0
#
#                                          idp_average  \
# 0  [[0.0, 0.988], [1.0, 0.938], [2.0, 0.98], [3.0...
# 1  [[0.0, 1.7613333333333334], [1.0, 1.636], [2.0...
# ...

# %%
## Negative lambda plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
import itertools


# importing pandas
import pandas as pd
 
# reading pickle
df = pd.read_pickle('simulations_df.pkl')
 
# set the max columns to none
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

#print(df.shape)
#display(df)

def choose_cmap_color(value, prop, PROTEINS, DRUGS, CONC, TEMPS, LAMBDAS):

    # TEMPS = [290, 300, 310, 315, 320, 323, 325, 330]
    # LAMBDAS = ["None", 0.0, 0.175, 0.35, 0.525, 0.7]
    # CONC = [0.2, 2.0, 10, 20.0]
    print("conc:", CONC)

    if prop in ["temperature", "T", "temp", "t"]:
        col_arr = plt.cycler("color", plt.cm.viridis(np.linspace(0, 1, len(TEMPS))))
        col_val = np.array(col_arr)[TEMPS.index(value)]
        print("value: ", value)

    elif prop in ["lambda", "l", "lam", "lamb"]:
        # default plasma
        # cool in the YRD presentation
        col_arr = plt.cycler("color", plt.cm.plasma(np.linspace(0, 1, len(LAMBDAS))))
        col_val = np.array(col_arr)[LAMBDAS.index(value)]

    elif prop in ["conc", "c", "conc"]:
        col_arr = plt.cycler("color", plt.cm.winter(np.linspace(0, 1, len(CONC))))
        col_val = np.array(col_arr)[CONC.index(value)]

    elif prop in ["both"]:
        combin = list(itertools.product(TEMPS, LAMBDAS))
        # print("combin: ", combin)
        col_arr = plt.cycler("color", plt.cm.magma(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    elif prop in ["conc_temp"]:
        combin = list(itertools.product(TEMPS, CONC))
        col_arr = plt.cycler("color", plt.cm.cool(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    elif prop in ["conc_lambda", "lambda_conc"]:
        combin = list(itertools.product(LAMBDAS, CONC))
        print("combin: ", combin)
        print(value)
        col_arr = plt.cycler("color", plt.cm.viridis(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    elif prop in ["all", "conc_lambda_temp"]:
        combin = list(itertools.product(TEMPS, LAMBDAS, CONC))
        col_arr = plt.cycler("color", plt.cm.prism(np.linspace(0, 1, len(combin))))
        col_val = np.array(col_arr)[combin.index(value)]

    return col_val["color"]


def plot_averages(type):


    for cc in CONC:
        #print("\ncc: ", cc)
        for lamb in LAMBDAS:
            prop_avg = []
            #print("lamb: ", lamb)
            for T in TEMPS:
                entry = df.loc[(df.conc == cc) & (df.lambd == lamb) & (df.temp == T) & (df.sigma == 0.450)]
                if type == "idp":
                    try:
                        # print("entry.idp_average: ", entry.idp_plat_avg.values[0])
                        prop_avg.append(entry.idp_plat_avg.values[0])
                        #print("T: ", T, "avg", entry.idp_plat_avg.values[0])
                    except IndexError:
                        prop_avg.append(None)
                elif type == "drg":
                    try:
                        # print("entry.idp_average: ", entry.idp_plat_avg.values[0])
                        prop_avg.append(entry.drg_plat_avg.values[0])
                    except IndexError:
                        prop_avg.append(None)

            # prop_avg = []

            col = choose_cmap_color(
                lamb, "lambda", ["Q5"], ["GLY"], CONC, TEMPS, LAMBDAS
            )

            if cc == 10.0:
                mark = "^"
            elif cc == 15.0:
                mark = "P"
            elif cc == 20.0:
                mark = "o"
            else:
                mark = "o"

            if type == "idp":
                label_text = f"$\\lambda$ = {lamb}\n{cc}mM"
            elif type == "drg":
                label_text = f"$\\lambda$ = {lamb}\n{cc}mM"

            # Checking if there is any "None" value in the average list (if the
            # simulation has not been performed)
            prop_avg = np.array(prop_avg)
            mask = pd.isnull(prop_avg)
            prop_avg = (prop_avg[~mask])
            T_masked = (np.array(TEMPS)[~mask])
                
            # Converting the particle count to concentration
            # total cell volume in L: 3.375e-20
            # volume of the condensed phase: 4.275e-21
            # bin volume: 1e3*15e-9*15e-9*1e-9
            
            bin_vol = 1e3*15e-9*15e-9*1e-9
            x_conc = prop_avg * (1/6.02e23) * (1/bin_vol) * 1000 * (1/167) 
                
            #print("temp",T,"prop_avg: ", prop_avg)
            plt.plot(
                x_conc,
                T_masked,
                markersize=20,
                marker=mark,
                linestyle=":",
                lw=5,
                color=col,
                label=label_text,
            )

    #l_315_avg = [578.850105263158, 1.7949473684210526]
    #l_323_avg = [536.6486315789474, 1.8348070175438598]
    #l_315_ext = [581.0241754385966, 1.7608070175438597]

    #plt.plot(l_315_avg[0], 323, "s", color="red", label=r"$0.350\ 315K \rightarrow 323K$")
    #plt.plot(l_315_ext[0], 315, "s", color="magenta", label="0.350 315K extended")
    #plt.plot(l_323_avg[0], 315, "s", color="blue", label=r"$0.350\ 323K \rightarrow 315K$")

    nodrg_entries = df[df.small_molec != 'GLY'][df.temp < 370]
    x_conc_idp = nodrg_entries.idp_plat_avg * (1/6.02e23) * (1/bin_vol) * 1000 * (1/167)
    
    plt.plot(
        x_conc_idp,
        nodrg_entries.temp,
        markersize=14,
        marker='o',
        linestyle="None",
        lw=5,
        color='cyan',
        label='NODRG',
        alpha=0.7,
        markeredgewidth=1.5,
        mec='black',
        #path_effects=[pe.Stroke(linewidth=1, foreground='black')],
    )

    plt.xlabel("Average density", fontsize=25)
    plt.legend(
        framealpha=0,
        fontsize=13,
        bbox_to_anchor=(0, 1, 1, 0),
        ncol=3,
        mode="expand",
        markerscale=0.8,
    )
    plt.ylabel("Temperature (K)", fontsize=25)
    # plt.yticks(
    #     [270, 280, 290, 300, 310, 320, 330, 340, 350],
    #     [270, 280, 290, 300, 310, 320, 330, 340, 350],
    # )
    #plt.grid()
    plt.tight_layout()

    
    plt.savefig("neg_lambdas_concentration.svg",dpi=500)
    plt.show()


TEMPS = [
    270,
    290,
    300,
    310,
    315,
    320,
    323,
    330,
    340,
    350,
    #370
]
LAMBDAS = [
    -0.7,
    #-0.1,
    #0,
    #0.175,
    #0.350,
    #0.525,
    0.7,
    #0.9,
    # "None",
    # None,
]
CONC = [
    # 0.0,
    # None,
    # 0.2,
    # 2.0,
    # 10.0,
    # 15.0,
    20.0,
]

#hash_del_list = []

#for hash_id in hash_del_list:
    #print(hash_id)
    #print(df.index[df['hash'] == hash_id])
 #   ind = df.index[df['hash'] == hash_id][0]
 #   df.drop(ind, inplace=True)

#db_path = ("simulations_df.pkl")
#df = df.drop(index=84)
#df = df.drop(index=86)
#df = df.drop(index=91)
#df = df.drop(index=134)
#df = df.drop(index=92)
#df = df.drop(index=132)
# df = pd.read_pickle(db_path)

# display(df[df.small_molec == None].sort_values('temp', axis=0))

plt.rc("font", family="serif")
plt.rcParams.update({"font.size": 25})
plt.tick_params(labelsize=25)
plt.rcParams["axes.linewidth"] = 0.5
plt.style.use("seaborn-poster")

plot_averages(type="idp")
# Out:
# conc: [20.0]
# conc: [20.0]
# /tmp/ipykernel_25477/3165090237.py:148: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   nodrg_entries = df[df.small_molec != 'GLY'][df.temp < 370]
